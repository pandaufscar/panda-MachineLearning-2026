# %% [markdown]
# #Exercício 1:
# Faça um programa
# que pede um número e diz se é
# par ou ímpar (if/else)

# %%
numero = input("Insira um número: ")

if int(numero) % 2 == 0:
  print("É par")
else:
  print("É impar")
# Out:
# Insira um número: 23
# É impar

# %% [markdown]
# #Exercício 2:
# Use um loop for para
# somar todos os números de 1 a
# 100.

# %%
soma = 0
for i in range (1, 101):
  soma = i + soma
print(soma)
# Out:
# 5050

# %% [markdown]
# #Exercício 3:
# Crie uma função que
# recebe uma lista e retorna o
# maior valor

# %%
import numpy as np
def maior_valor(lista):
  maior = lista[0]
  for i in lista:
    if i > maior:
      maior = i
  return maior

lista = np.random.randint(1, 100, 10)
print(lista)
print(maior_valor(lista))
# Out:
# [68 33 42 30 39 92  8 96 23 86]
# 96
