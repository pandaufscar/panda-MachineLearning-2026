# %% [markdown]
# 1.   Lista de compras
#
# Crie uma lista com 5 itens de supermercado.
# Depois:
# Adicione mais um item
# Mostre o terceiro item da lista
#
#
# 2.   Cadastro de aluno
#
#
#
# Crie um dicionário com:
# nome
# idade
# curso
# 3 notas (em uma lista)
#
# Depois, mostre apenas o nome e a média das notas
#
# 3. Criar um pequeno programa que:
#
# Guarde informações de 3 amigos (nome,
# idade, cidade)
#
# Use uma lista de dicionários

# %%
# Exercício 1
import pandas as pd

list_compras = ['arroz', 'feijao', 'ovo', 'alface', 'carne']
list_compras.append('frango')
print(list_compras[2])
# Out:
# ovo

# %%
# Exercício 2
cadastro = {
    "nome": 'Ana',
    "idade": 20,
    "curso":'bcc',
    "notas": [7,8,9]
}

media = sum(cadastro['notas']) / len(cadastro['notas'])

print(cadastro['nome'])
print(media)
# Out:
# Ana
# 8.0

# %%
# Exercício 3
amigos = [
    {'nome': 'andre',
     'idade':20,
     'cidade':'São Carlos'
     },
    {
        'nome':'beatriz',
        'idade':19,
        'cidade': 'ribeirao preto'
    },
    {
        'nome': 'cristina',
        'idade':21,
        'cidade':'campinas'
    }
]

for amigo in amigos:
    print("Nome:", amigo["nome"])
    print("Idade:", amigo["idade"])
    print("Cidade:", amigo["cidade"])
# Out:
# Nome: andre
# Idade: 20
# Cidade: São Carlos
# Nome: beatriz
# Idade: 19
# Cidade: ribeirao preto
# Nome: cristina
# Idade: 21
# Cidade: campinas
